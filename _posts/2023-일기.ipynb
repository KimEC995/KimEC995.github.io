# %% [markdown]
# # 강의
#
# ### 2022. 대학교 아두이노 특강
#
# 평소 알고 지내던 기공과 교수님께서 기회를 주셨다. 기공과 학생들 소프트웨어 지식이 부족하니 교양 겸 특강 한번 하자고. 여러번 강의 해봤지만 대학 특강은 처음이어서 승낙했다. 대상은 기공과와 공예과 3~4학년 학생들. 공예과 학생은 공예과 교수님이 모아주셨다. 감사합니다..
#
# 두 학과의 친구들 모두 소프트웨어적인 기초가 부족하다 들어 기초부터 시작했다. 임베디드 기초를 들어가면 너무 어렵고 시간이 부족하니

# %% [markdown]
# # 231018-GCP-Streamlit / DashBoard

# %% [markdown]
# requirements.txt 로 관리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [링크](https://lookerstudio.google.com/navigation/reporting)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# 전부아니요

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install --upgrade google-cloud-bigquery
#
# 빅쿼리 연동 + 스트림릿

# %% [markdown]
# # 사용자인증정보만들기
#
# API 서비스 => 사용자 인증정보 => 만들기 => API키
#
# 키 생성되ㅁ => 다른데서 씀
#
#
# 서비스 계정관리 => 만들기 => ![image.png](attachment:image.png)

# %% [markdown]
# 로컬에서 Gcloud 사용할때 사용함

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 681078421585-compute@developer.gserviceaccount.com

# %%
import streamlit as st
import pandas as pd
# Perform query.
# Uses st.cache_data to only rerun when the query changes or after 10 min.
def main():
    st.title("The query data 가져오기")
    

def main():
    
    st.title("Streamlit Iris Data Visualization")

    

if __name__ == '__main__': 
    main()

# %%
streamlit run main.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 수정 => vi 편집
#
# 깃 푸쉬 => 깃에서 csv 업로드 => git pull => 확인 => vi 수정

# %%
# -*-- coding:utf-8 -*-

# 수정코드
import streamlit as st
import pandas as pd
# Perform query.
# Uses st.cache_data to only rerun when the query changes or after 10 min.
def main():
    st.title("The query data 가져오기")


def main():

    st.title("Streamlit Iris Data Visualization")
    st.title("Write in GCP")
    df = pd.read_csv("iris.csv")
    st.write(df)

if __name__ == '__main__':
    main()

# %% [markdown]
# ![image.png](attachment:image.png)
